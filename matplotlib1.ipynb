# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
#create an example
x=np.arange(0,10)
y=np.arange(11,21)

# %%
a=np.arange(40,50)
b=np.arange(50,60)

# %%
#ploting with matplotlib
#sctter plot
plt.scatter(x,y,c='r')
plt.xlabel('X axis')
plt.ylabel('Y axis')
plt.title('graph in 2D')
# Out:
# Text(0.5, 1.0, 'graph in 2D')

# %%
y=x*x

# %%
##plt plot
plt.plot(x,y,'r')

# %%
np.pi
# Out:
# 3.141592653589793

# %%
x=np.arange(0,4*np.pi,0.1)
y=np.sin(x)
plt.plot(x,y)
# plt.savefig("first.png")

# %%
##Bar plot
x=[2,8,10]
y=[11,16,9]
x2=[3,9,11]
y2=[6,15,7]
plt.bar(x,y)
plt.bar(x2,y2)
plt.show()

# %%
##histogram
a=np.array([22,87,5,43,56,73,55,54,11,20,51,5,79,31,27])
plt.hist(a)
# Out:
# (array([3., 1., 2., 1., 1., 2., 2., 0., 1., 2.]),
#  array([ 5. , 13.2, 21.4, 29.6, 37.8, 46. , 54.2, 62.4, 70.6, 78.8, 87. ]),
#  <BarContainer object of 10 artists>)

# %%
##boxplot
data=[np.random.normal(0,std,100)for std in range(1,4)]
plt.boxplot(data,vert=True,patch_artist=True)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1836de953d0>,
#   <matplotlib.lines.Line2D at 0x1836decd210>,
#   <matplotlib.lines.Line2D at 0x1836dee6890>,
#   <matplotlib.lines.Line2D at 0x1836deda590>,
#   <matplotlib.lines.Line2D at 0x1836dccb6d0>,
#   <matplotlib.lines.Line2D at 0x1836dccb250>],
#  'caps': [<matplotlib.lines.Line2D at 0x1836decf050>,
#   <matplotlib.lines.Line2D at 0x1836ded9050>,
#   <matplotlib.lines.Line2D at 0x1836de5a4d0>,
#   <matplotlib.lines.Line2D at 0x1836dc54fd0>,
#   <matplotlib.lines.Line2D at 0x1836dcc8710>,
#   <matplotlib.lines.Line2D at 0x1836dcc2950>],
#  'boxes': [<matplotlib.patches.PathPatch at 0x1836dec7f90>,
#   <matplotlib.patches.PathPatch at 0x1836ded8c50>,
#   <matplotlib.patches.PathPatch at 0x1836dcd1410>],
#  'medians': [<matplotlib.lines.Line2D at 0x1836dedb250>,
#   <matplotlib.lines.Line2D at 0x1836dcd1350>,
#   <matplotlib.lines.Line2D at 0x1836dee5590>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1836dd14550>,
#   <matplotlib.lines.Line2D at 0x1836dec6550>,
#   <matplotlib.lines.Line2D at 0x1836dee6910>],
#  'means': []}

# %%
##pie chart
lebel=['python','rubby','c++','java']
sizes = [215,130,245,210]
explode=[0,0,0.1,0]
plt.pie(sizes,explode=explode,labels=lebel,autopct='%1.1f%%',shadow=True)
plt.axis('equal')
# Out:
# (-1.190587029494329, 1.1043136680711585, -1.149857217818856, 1.102373774725303)
